# %% [markdown]
# # Tarea 2: Análisis geoespacial de hospitales en Perú

# %% [markdown]
# ### Grupo 7
#
# Grabiel
#
# Eduardo
#
# Romel
#
# Lizeth

# %%
#%pip install -r requirements.txt

# %%
# Impotación de librerías
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
import matplotlib.pyplot as plt
import mapclassify
import numpy as np

# %% [markdown]
# # Tarea: Análisis geoespacial de hospitales en el Perú

# %% [markdown]
# ### 1 Confirguración del repositorio : creación del repositorio   -->  Hospitals-Access-Peru
# ### 2 Geospatial Analysis with GeoPandas

# %% [markdown]
# 2.1. Hospitals (MINSA – IPRESS)

# %%
# URL de los hospitales del MINSA
url = "https://datosabiertos.gob.pe/node/2998/download"

# Cargando BD: separador coma
try:
    hospitales = pd.read_csv(url, encoding="latin-1")
except:
    # Cargando BD: separador punto y coma
    hospitales = pd.read_csv(url, sep=";", encoding="latin-1")

# 1. Filtrar solo HOSPITALES en funcionamiento/operativos
hospitales_operativos = hospitales[hospitales["Condición"] == "EN FUNCIONAMIENTO"]

# 2 Filtrar coordenadas válidas ---
hospitales_operativos_geo = hospitales_operativos[
    (hospitales_operativos["NORTE"].notnull()) & (hospitales_operativos["NORTE"] != 0) & 
    (hospitales_operativos["ESTE"].notnull()) &  (hospitales_operativos["ESTE"] != 0) ]
    
# 3 Seleccionar solo las columnas que necesito
hospitales_final = hospitales_operativos_geo[
    [   "Institución",
        "Nombre del establecimiento",
        "Clasificación",
        "UBIGEO",
        "Departamento",
        "Provincia",
        "Distrito",
        "Estado",
        "NORTE",
        "ESTE" ]]

# Renombrar columnas NORTE → latitud, ESTE → longitud   en el mismo DataFrame : hospitales_final
hospitales_final.rename(
    columns={"NORTE": "latitud", "ESTE": "longitud"},
    inplace=True)

# Verificar resultado
print(hospitales_final.head(2))
print("Total hospitales operativos:", len(hospitales_final))
# Out:
#          Institución Nombre del establecimiento  \
# 1  GOBIERNO REGIONAL                     AMBATO
# 2  GOBIERNO REGIONAL  SANTA ISABEL DE YUMBATURO
#
#                         Clasificación  UBIGEO Departamento Provincia  \
# 1  PUESTOS DE SALUD O POSTAS DE SALUD   60611    CAJAMARCA   CUTERVO
# 2  PUESTOS DE SALUD O POSTAS DE SALUD  160302       LORETO    LORETO
#
#      Distrito    Estado    latitud  longitud
# 1  SANTA CRUZ  ACTIVADO -78.858380 -6.133523
# 2    PARINARI  ACTIVADO -74.258139 -4.581509
# Total hospitales operativos: 7939
# C:\Users\lmoreno\AppData\Local\Temp\ipykernel_21516\826607914.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospitales_final.rename(

# %% [markdown]
# 2.2. Centros de Población (INEI)  --> shape_file_CP

# %%
# Ruta relativa desde "code"

centro_poblado = gpd.read_file('shape_file_CP/CCPP_IGN100K.shp')
centro_poblado
# Out:
#         OBJECTID         NOM_POBLAD FUENTE      CÓDIGO CAT_POBLAD        DIST  \
# 0              1         PANDISHARI   INEI  2502010002      OTROS    RAYMONDI
# 1              2            CHICOSA   INEI  2502010003      OTROS    RAYMONDI
# 2              3               RAYA    IGN  2502010004      OTROS    RAYMONDI
# 3              4        PENSILVANIA   INEI  2502010005      OTROS    RAYMONDI
# 4              5        PONTE VEDRA   INEI  2502010006    CASERÍO    RAYMONDI
# ...          ...                ...    ...         ...        ...         ...
# 136582    136584               IPAN   INEI        None       None    ZORRITOS
# 136583    136585              URBAN   INEI        None       None    ZORRITOS
# 136584    136586  PAJONAL MAJONTONI    IGN        None       None    RAYMONDI
# 136585    136587        AGUA BLANCA   INEI  2501020043    CASERÍO  CAMPOVERDE
# 136586    136588          PRIMAVERA   INEI  2503020032    CASERÍO     IRAZOLA
#
#                          PROV      DEP CÓD_INT             CATEGORIA  \
# 0                     ATALAYA  UCAYALI    2050  Centro Poblado Menor
# 1                     ATALAYA  UCAYALI    2050  Centro Poblado Menor
# 2                     ATALAYA  UCAYALI    2350  Centro Poblado Menor
# 3                     ATALAYA  UCAYALI    2050  Centro Poblado Menor
# 4                     ATALAYA  UCAYALI    2050  Centro Poblado Menor
# ...                       ...      ...     ...                   ...
# 136582  CONTRALMIRANTE VILLAR   TUMBES    None                  None
# 136583  CONTRALMIRANTE VILLAR   TUMBES    None                  None
# 136584                ATALAYA  UCAYALI    2049  Centro Poblado Menor
# 136585       CORONEL PORTILLO  UCAYALI    1953  Centro Poblado Menor
# 136586             PADRE ABAD  UCAYALI    1853  Centro Poblado Menor
#
#                X         Y           N_BUSQDA                 geometry
# 0      -74.06462 -10.37129         PANDISHARI  POINT (-74.065 -10.371)
# 1      -74.06153 -10.37852            CHICOSA  POINT (-74.062 -10.379)
# 2      -72.94118 -10.33043               RAYA   POINT (-72.941 -10.33)
# 3      -74.05988 -10.40401        PENSILVANIA   POINT (-74.06 -10.404)
# 4      -74.03788 -10.41809        PONTE VEDRA  POINT (-74.038 -10.418)
# ...          ...       ...                ...                      ...
# 136582 -81.02462 -81.02462               None  POINT (-81.025 -4.0973)
# 136583 -80.84055 -80.84055               None   POINT (-80.841 -4.068)
# 136584 -74.35804 -74.35804  PAJONAL MAJONTONI  POINT (-74.358 -10.727)
# 136585 -74.78089 -74.78089        AGUA BLANCA  POINT (-74.781 -8.6051)
# 136586 -75.02997 -75.02997          PRIMAVERA   POINT (-75.03 -8.8764)
#
# [136587 rows x 14 columns]

# %% [markdown]
# 2.3 Límites Administrativos (Distritos del Perú) --- > shape_file_distritos

# %%
# Ruta relativa desde "code"
maps = gpd.read_file('shape_file_distritos/DISTRITOS.shp')
maps
# Out:
#      IDDPTO DEPARTAMEN IDPROV      PROVINCIA  IDDIST                DISTRITO  \
# 0        10    HUANUCO   1009    PUERTO INCA  100902         CODO DEL POZUZO
# 1        10    HUANUCO   1009    PUERTO INCA  100904             TOURNAVISTA
# 2        25    UCAYALI   2503     PADRE ABAD  250305  ALEXANDER VON HUMBOLDT
# 3        25    UCAYALI   2503     PADRE ABAD  250302                 IRAZOLA
# 4        25    UCAYALI   2503     PADRE ABAD  250304                 NESHUYA
# ...     ...        ...    ...            ...     ...                     ...
# 1868     10    HUANUCO   1006  LEONCIO PRADO  100608         CASTILLO GRANDE
# 1869     10    HUANUCO   1006  LEONCIO PRADO  100609            PUEBLO NUEVO
# 1870     10    HUANUCO   1006  LEONCIO PRADO  100610   SANTO DOMINGO DE ANDA
# 1871     21       PUNO   2111      SAN ROMAN  211105              SAN MIGUEL
# 1872     15       LIMA   1508         HUAURA  150806                  HUAURA
#
#                      CAPITAL CODCCPP  AREA FUENTE  \
# 0            CODO DEL POZUZO    0001     1   INEI
# 1                TOURNAVISTA    0001     1   INEI
# 2     ALEXANDER VON HUMBOLDT    0001     1   INEI
# 3              SAN ALEJANDRO    0001     1   INEI
# 4               MONTE ALEGRE    0001     1   INEI
# ...                      ...     ...   ...    ...
# 1868         CASTILLO GRANDE    0001     1   INEI
# 1869            PUEBLO NUEVO    0001     1   INEI
# 1870                   PACAE    0001     1   INEI
# 1871              SAN MIGUEL    0001     1   INEI
# 1872                  HUAURA    0001     1   INEI
#
#                                                geometry
# 0     POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 1     POLYGON ((-74.641 -8.823, -74.64 -8.8285, -74....
# 2     POLYGON ((-75.023 -8.7419, -75.023 -8.7423, -7...
# 3     POLYGON ((-75.139 -8.5671, -75.14 -8.5697, -75...
# 4     POLYGON ((-75.016 -8.4464, -75.016 -8.4466, -7...
# ...                                                 ...
# 1868  POLYGON ((-76.081 -9.1302, -76.08 -9.1303, -76...
# 1869  POLYGON ((-75.888 -9.0091, -75.888 -9.0101, -7...
# 1870  POLYGON ((-75.911 -8.8859, -75.912 -8.8868, -7...
# 1871  POLYGON ((-70.132 -15.334, -70.124 -15.337, -7...
# 1872  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
#
# [1873 rows x 11 columns]

# %% [markdown]
# 2.4 Tarea 1: Mapas estáticos: recuento de hospitales por distrito

# %%
#Chequear valores únicos en el shape_file_distritos
maps['IDDIST'].is_unique
# Out:
# True

# %%
maps['IDDIST'].unique().size
# Out:
# 1873

# %%
# Seleccionar solo las columnas relevantes
maps = maps[['IDDIST', 'geometry']]
maps = maps.rename({'IDDIST':'UBIGEO'}, axis =1 )
maps
# Out:
#       UBIGEO                                           geometry
# 0     100902  POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 1     100904  POLYGON ((-74.641 -8.823, -74.64 -8.8285, -74....
# 2     250305  POLYGON ((-75.023 -8.7419, -75.023 -8.7423, -7...
# 3     250302  POLYGON ((-75.139 -8.5671, -75.14 -8.5697, -75...
# 4     250304  POLYGON ((-75.016 -8.4464, -75.016 -8.4466, -7...
# ...      ...                                                ...
# 1868  100608  POLYGON ((-76.081 -9.1302, -76.08 -9.1303, -76...
# 1869  100609  POLYGON ((-75.888 -9.0091, -75.888 -9.0101, -7...
# 1870  100610  POLYGON ((-75.911 -8.8859, -75.912 -8.8868, -7...
# 1871  211105  POLYGON ((-70.132 -15.334, -70.124 -15.337, -7...
# 1872  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
#
# [1873 rows x 2 columns]

# %%
# Asegurar que el conjunto de datos esté en WGS-84 (EPSG:4326)
maps = maps.to_crs(epsg=4326)
maps.crs   # Muestra el sistema de coordenadas actual del GeoDataFrame
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
maps.dtypes
# Out:
# UBIGEO        object
# geometry    geometry
# dtype: object

# %%
# Convertir a texto y luego a entero
maps['UBIGEO'] = maps['UBIGEO'].astype(str).astype(int)
maps
# Out:
#       UBIGEO                                           geometry
# 0     100902  POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 1     100904  POLYGON ((-74.641 -8.823, -74.64 -8.8285, -74....
# 2     250305  POLYGON ((-75.023 -8.7419, -75.023 -8.7423, -7...
# 3     250302  POLYGON ((-75.139 -8.5671, -75.14 -8.5697, -75...
# 4     250304  POLYGON ((-75.016 -8.4464, -75.016 -8.4466, -7...
# ...      ...                                                ...
# 1868  100608  POLYGON ((-76.081 -9.1302, -76.08 -9.1303, -76...
# 1869  100609  POLYGON ((-75.888 -9.0091, -75.888 -9.0101, -7...
# 1870  100610  POLYGON ((-75.911 -8.8859, -75.912 -8.8868, -7...
# 1871  211105  POLYGON ((-70.132 -15.334, -70.124 -15.337, -7...
# 1872  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
#
# [1873 rows x 2 columns]

# %% [markdown]
# ### Merge: Hospitales & ShapefileDistritos

# %%
# Merge using inner way to drop missing values 
dataset_cv = pd.merge(maps, hospitales_final, how="inner", on="UBIGEO")
dataset_cv
# Out:
#       UBIGEO                                           geometry  \
# 0     100902  POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 1     100902  POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 2     100902  POLYGON ((-75.318 -9.2953, -75.317 -9.2976, -7...
# 3     100904  POLYGON ((-74.641 -8.823, -74.64 -8.8285, -74....
# 4     100904  POLYGON ((-74.641 -8.823, -74.64 -8.8285, -74....
# ...      ...                                                ...
# 7886  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
# 7887  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
# 7888  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
# 7889  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
# 7890  150806  POLYGON ((-77.376 -10.897, -77.376 -10.897, -7...
#
#             Institución            Nombre del establecimiento  \
# 0     GOBIERNO REGIONAL                       CODO DEL POZUZO
# 1     GOBIERNO REGIONAL                            HUAMPOMAYO
# 2     GOBIERNO REGIONAL                           CHORROPAMPA
# 3     GOBIERNO REGIONAL                       PRINCIPE DE PAZ
# 4     GOBIERNO REGIONAL                           TOURNAVISTA
# ...                 ...                                   ...
# 7886  GOBIERNO REGIONAL                                PEÑICO
# 7887            ESSALUD  CENTRO DE ATENCION PRIMARIA I HUMAYA
# 7888  GOBIERNO REGIONAL                           VILCAHUAURA
# 7889  GOBIERNO REGIONAL                                HUMAYA
# 7890  GOBIERNO REGIONAL                               SOCORRO
#
#                            Clasificación Departamento    Provincia  \
# 0     CENTROS DE SALUD O CENTROS MEDICOS      HUANUCO  PUERTO INCA
# 1     PUESTOS DE SALUD O POSTAS DE SALUD      HUANUCO  PUERTO INCA
# 2     PUESTOS DE SALUD O POSTAS DE SALUD      HUANUCO  PUERTO INCA
# 3     PUESTOS DE SALUD O POSTAS DE SALUD      HUANUCO  PUERTO INCA
# 4     CENTROS DE SALUD O CENTROS MEDICOS      HUANUCO  PUERTO INCA
# ...                                  ...          ...          ...
# 7886  PUESTOS DE SALUD O POSTAS DE SALUD         LIMA       HUAURA
# 7887  PUESTOS DE SALUD O POSTAS DE SALUD         LIMA       HUAURA
# 7888  PUESTOS DE SALUD O POSTAS DE SALUD         LIMA       HUAURA
# 7889  PUESTOS DE SALUD O POSTAS DE SALUD         LIMA       HUAURA
# 7890  CENTROS DE SALUD O CENTROS MEDICOS         LIMA       HUAURA
#
#              Distrito    Estado    latitud   longitud
# 0     CODO DEL POZUZO  ACTIVADO -75.463665  -9.669402
# 1     CODO DEL POZUZO  ACTIVADO -75.591200  -9.969250
# 2     CODO DEL POZUZO  ACTIVADO -75.394620  -9.850610
# 3         TOURNAVISTA  ACTIVADO -74.683542  -8.995790
# 4         TOURNAVISTA  ACTIVADO -74.702805  -8.934338
# ...               ...       ...        ...        ...
# 7886           HUAURA  ACTIVADO -77.437500 -10.931177
# 7887           HUAURA  ACTIVADO -77.409616 -11.098534
# 7888           HUAURA  ACTIVADO -77.474190 -11.072751
# 7889           HUAURA  ACTIVADO -77.409943 -11.099675
# 7890           HUAURA  ACTIVADO -77.605749 -11.070700
#
# [7891 rows x 11 columns]

# %%
# 1) Definir bins como límites superiores
bins = [5, 10, 20, 30, 40, 50, mapa['Hosp_Publicos'].max()]

# 2) Poner a NaN los ceros para mostrarlos como "Sin datos"
mapa['Hosp_Publicos'] = mapa['Hosp_Publicos'].astype(int)
mapa.loc[mapa['Hosp_Publicos'] == 0, 'Hosp_Publicos'] = np.nan

# 3) Plot
fig, ax = plt.subplots(figsize=(9,10))
ax.set_axis_off()

mapa.plot(
    column='Hosp_Publicos',
    cmap='OrRd',
    scheme='UserDefined',                 # <-- como string
    classification_kwds={'bins': bins},   # límites superiores
    edgecolor='white', linewidth=0.2,
    legend=True, ax=ax,
    legend_kwds={
        "labels": ["1 a 5", "5 a 10", "10 a 20", "20 a 30", "30 a 40", "40 a 50", "más de 50"],
        "title": "Número de hospitales públicos"
    },
    missing_kwds={'color':'lightgrey','label':'Sin datos'}
)

ax.set_title('Hospitales públicos por distrito', fontsize=14, pad=10)
plt.tight_layout()
plt.show()

# %%
# Verificando el número de hospitales públicos

hosp_pub = dataset_cv[dataset_cv['Institución'].isin(publicas)].copy()

# Agrupar por distrito y contar
tabla = (hosp_pub
         .groupby(['UBIGEO','Distrito'], as_index=False)
         .size()
         .rename(columns={'size':'Hosp_Publicos'}))

# Ordenar de mayor a menor
tabla = tabla.sort_values('Hosp_Publicos', ascending=False).reset_index(drop=True)

print(tabla.head(10))  # muestra los 10 distritos con más hospitales públicos
# Out:
#    UBIGEO                Distrito  Hosp_Publicos
# 0  060601                 CUTERVO             55
# 1  010205                   IMAZA             39
# 2  150132  SAN JUAN DE LURIGANCHO             36
# 3  060701              BAMBAMARCA             35
# 4  070101                  CALLAO             35
# 5  160201              YURIMAGUAS             34
# 6  060401                   CHOTA             32
# 7  250101                CALLERIA             31
# 8  010701            BAGUA GRANDE             30
# 9  200201                 AYABACA             30

# %% [markdown]
# # Tarea 2 – Análisis geoespacial con GeoPandas (Nivel Departamental)
#
# **Objetivo:**
# - Filtrar hospitales **operativos** (IPRESS – MINSA/SUSALUD).
# - Mantener sólo coordenadas válidas (**latitud/longitud**).
# - Agregar **número de hospitales por Departamento**.
# - Identificar **departamento(s) con más y menos** hospitales.
# - Presentar:
#   - **Tabla** (ordenada desc.),
#   - **Gráfico de barras** (matplotlib),
#   - **Mapa coroplético** a nivel departamental (GeoPandas, **EPSG:4326**).
#
# > En Perú, **latitud ~ [-18, 0]** y **longitud ~ [-81, -68]**. En el dataset suele venir `NORTE`/`ESTE`: por valores reales, **`NORTE ≈ longitud`** y **`ESTE ≈ latitud`**.

# %%
# Imports
import os, warnings
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

pd.set_option("display.max_colwidth", 120)
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# ## Parámetros (ajusta rutas según tus archivos)
# - Si quieres usar la **URL** oficial de IPRESS, deja `USAR_URL_IPRESS = True`.
# - Si prefieres un **CSV local**, pon `USAR_URL_IPRESS = False` y define `RUTA_IPRESS_LOCAL`.
# - Usa **límites departamentales** si los tienes, o **distritos** y activa `PARTIR_DE_DISTRITOS = True` para hacer `dissolve`.

# %%
# Parámetros
import os, glob
from pathlib import Path

USAR_URL_IPRESS = True
URL_IPRESS = "https://datosabiertos.gob.pe/node/2998/download"  # Fuente IPRESS (usada en Tarea 1)

# Si usas archivo local, desactiva la URL y completa la ruta:
RUTA_IPRESS_LOCAL = r"C:\ruta\a\tu\IPRESS.csv"

# === Límites departamentales ===
# Carpeta donde guardaste el shapefile de DEPARTAMENTOS (.shp + .dbf + .shx + .prj)
CARPETA_DEP = r"C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\code\shape_file_departamentos"

# Detecta automáticamente el .shp dentro de la carpeta
candidatos = glob.glob(os.path.join(CARPETA_DEP, "*.shp"))
if not candidatos:
    raise FileNotFoundError(f"No se encontró ningún .shp dentro de: {CARPETA_DEP}")

# Si hay varios, intenta escoger el que contenga 'dep' o 'depart' en el nombre
preferidos = [c for c in candidatos if any(k in os.path.basename(c).lower() for k in ["dep", "depart"])]
RUTA_LIMITE_DEPARTAMENTAL = preferidos[0] if preferidos else candidatos[0]

# No usaremos distritos (vamos directo con departamental)
PARTIR_DE_DISTRITOS = False
RUTA_DISTRITOS = r""

# Carpeta de salida
# Carpeta de salida (Windows)
OUT_DIR = Path(r"C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\output") / "salidas_tarea2"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("OUT_DIR ->", OUT_DIR)


print("Usando shapefile departamental:", RUTA_LIMITE_DEPARTAMENTAL)
OUT_DIR
# Out:
# OUT_DIR -> C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\output\salidas_tarea2
# Usando shapefile departamental: C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\code\shape_file_departamentos\geoBoundaries-PER-ADM1.shp
# WindowsPath('C:/Users/User/Documents/PROFE_CHRISTIAN/Hospitals-Access-Peru/output/salidas_tarea2')

# %% [markdown]
# ## 1) Cargar IPRESS (MINSA/SUSALUD) y validar lectura
# Se intenta con separador `,` y luego `;` usando `latin-1`. Si usas local, indica la ruta.

# %%
def leer_ipress(url: str | None, local_path: str | None) -> pd.DataFrame:
    if url and USAR_URL_IPRESS:
        for sep in (",", ";"):
            try:
                df = pd.read_csv(url, sep=sep, encoding="latin-1", low_memory=False)
                if df.shape[1] >= 5:
                    return df
            except Exception:
                pass
        raise RuntimeError("No pude leer IPRESS desde la URL con ',' ni ';'.")
    else:
        if not local_path or not os.path.exists(local_path):
            raise FileNotFoundError("Define RUTA_IPRESS_LOCAL correctamente.")
        return pd.read_csv(local_path, encoding="latin-1", low_memory=False)

ipress_raw = leer_ipress(URL_IPRESS if USAR_URL_IPRESS else None,
                         RUTA_IPRESS_LOCAL if not USAR_URL_IPRESS else None)

ipress_raw.shape, ipress_raw.head(3)
# Out:
# ((20819, 33),
#           Institución  Código Único Nombre del establecimiento  \
#  0            PRIVADO         16618                 SONRIE MAS
#  1  GOBIERNO REGIONAL          7050                     AMBATO
#  2  GOBIERNO REGIONAL            99  SANTA ISABEL DE YUMBATURO
#
#                                                 Clasificación  \
#  0  CONSULTORIOS MEDICOS Y DE OTROS PROFESIONALES DE LA SALUD
#  1                         PUESTOS DE SALUD O POSTAS DE SALUD
#  2                         PUESTOS DE SALUD O POSTAS DE SALUD
#
#                                           Tipo Departamento Provincia  \
#  0  ESTABLECIMIENTO DE SALUD SIN INTERNAMIENTO         LIMA      LIMA
#  1  ESTABLECIMIENTO DE SALUD SIN INTERNAMIENTO    CAJAMARCA   CUTERVO
#  2  ESTABLECIMIENTO DE SALUD SIN INTERNAMIENTO       LORETO    LORETO
#
#              Distrito  UBIGEO  \
#  0  SANTIAGO DE SURCO  150140
#  1         SANTA CRUZ   60611
#  2           PARINARI  160302
#
#                                                        Dirección  ...  \
#  0  AV. CAMINOS DEL INCA 2028 OF.201, URBANIZACION LAS GARDENIAS  ...
#  1                                           COMUNIDAD DE AMBATO  ...
#  2                                                    ACTUALIZAR  ...
#
#     Inicio de Actividad  \
#  0           11/03/2013
#  1           29/06/2006
#  2           01/01/1900
#
#     Director Médico y/o Responsable de la Atención de Salud    Estado  \
#  0                          GILBERTO MARTIN AQUIJE GAVILAN   ACTIVADO
#  1                                     IDELSO MENOR CHAVEZ   ACTIVADO
#  2                             JULIO TONY CAITIMARI MACHOA   ACTIVADO
#
#    Situación          Condición Inspección      NORTE      ESTE    COTA CAMAS
#  0            EN FUNCIONAMIENTO                   NaN       NaN     NaN   NaN
#  1            EN FUNCIONAMIENTO            -78.858380 -6.133523  1724.0   NaN
#  2            EN FUNCIONAMIENTO            -74.258139 -4.581509   124.0   NaN
#
#  [3 rows x 33 columns])

# %% [markdown]
# ## 2) Filtrar **hospitales** en **operación** y mantener coordenadas válidas
# - Operativos: `Condición` contiene "FUNCION" **o** `Estado` contiene "ACTIV".
# - Clasificación: debe contener "HOSPITAL".
# - Columnas clave y renombre **NORTE→longitud**, **ESTE→latitud**.
# - `UBIGEO` como texto de 6 dígitos.

# %%
def filtrar_hospitales_operativos(df: pd.DataFrame) -> pd.DataFrame:
    mask_operativo = df["Condición"].astype(str).str.contains("FUNCION", case=False, na=False) | \
                     df["Estado"].astype(str).str.contains("ACTIV", case=False, na=False)
    mask_hospital  = df["Clasificación"].astype(str).str.contains("HOSPITAL", case=False, na=False)
    return df.loc[mask_operativo & mask_hospital].copy()

def seleccionar_columnas_y_coords(df: pd.DataFrame) -> pd.DataFrame:
    cols = ["Institución","Nombre del establecimiento","Clasificación","UBIGEO",
            "Departamento","Provincia","Distrito","Estado","NORTE","ESTE"]
    out = df.loc[:, cols].copy()
    # NORTE ≈ longitud | ESTE ≈ latitud
    out = out.rename(columns={"NORTE": "longitud", "ESTE": "latitud"})
    # Coordenadas válidas
    m_geo = out["latitud"].notna() & out["longitud"].notna() & (out["latitud"] != 0) & (out["longitud"] != 0)
    out = out.loc[m_geo].copy()
    # UBIGEO 6 dígitos
    out["UBIGEO"] = (out["UBIGEO"].astype(str).str.replace(r"\D", "", regex=True).str.zfill(6))
    return out

ipress_hosp = filtrar_hospitales_operativos(ipress_raw)
ipress_hosp = seleccionar_columnas_y_coords(ipress_hosp)

print("Filas filtradas:", len(ipress_hosp))
ipress_hosp[["Departamento","Provincia","Distrito","latitud","longitud"]].head(3)
# Out:
# Filas filtradas: 279
#    Departamento Provincia  Distrito    latitud   longitud
# 17         PUNO  AZANGARO  AZANGARO -14.904143 -70.199339
# 35       ANCASH   CARHUAZ   CARHUAZ  -9.277484 -77.649385
# 52  LA LIBERTAD    ASCOPE    ASCOPE  -7.714237 -79.101259

# %%
# Chequeo rápido de rangos: lat/long en Perú
print("latitud min/max:", ipress_hosp["latitud"].min(), ipress_hosp["latitud"].max())
print("longitud min/max:", ipress_hosp["longitud"].min(), ipress_hosp["longitud"].max())
# Out:
# latitud min/max: -18.017545 -3.55560167
# longitud min/max: -81.27384046 -69.090335

# %% [markdown]
# ## 3) Agregado por **Departamento** (tabla) e identificación de extremos

# %%
def agregar_por_departamento(df: pd.DataFrame) -> pd.DataFrame:
    return (
        df.groupby("Departamento", as_index=False)
          .size()
          .rename(columns={"size":"n_hospitales"})
          .sort_values("n_hospitales", ascending=False)
    )

dep_resumen = agregar_por_departamento(ipress_hosp)

max_n = dep_resumen["n_hospitales"].max()
min_n = dep_resumen["n_hospitales"].min()
dep_max = dep_resumen.loc[dep_resumen["n_hospitales"] == max_n, "Departamento"].tolist()
dep_min = dep_resumen.loc[dep_resumen["n_hospitales"] == min_n, "Departamento"].tolist()

print("Departamento(s) con MÁS hospitales (n={}): {}".format(max_n, ", ".join(dep_max)))
print("Departamento(s) con MENOS hospitales (n={}): {}".format(min_n, ", ".join(dep_min)))

dep_resumen.head(10)
# Out:
# Departamento(s) con MÁS hospitales (n=50): LIMA
# Departamento(s) con MENOS hospitales (n=3): TACNA
#    Departamento  n_hospitales
# 14         LIMA            50
# 12  LA LIBERTAD            33
# 1        ANCASH            17
# 20         PUNO            14
# 11        JUNIN            13
# 3      AREQUIPA            12
# 19        PIURA            12
# 21   SAN MARTIN            11
# 4      AYACUCHO            11
# 5     CAJAMARCA            11

# %%
# Exportar tabla resumen
out_csv = os.path.join(OUT_DIR, "resumen_departamental_hospitales.csv")
dep_resumen.to_csv(out_csv, index=False, encoding="utf-8")
out_csv
# Out:
# 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\salidas_tarea2\\resumen_departamental_hospitales.csv'

# %% [markdown]
# ## 4) Gráfico de barras (matplotlib)

# %%
plt.figure()
plt.bar(dep_resumen["Departamento"], dep_resumen["n_hospitales"])
plt.xticks(rotation=90)
plt.title("Total de hospitales públicos operativos por departamento")
plt.xlabel("Departamento")
plt.ylabel("N° hospitales")
plt.tight_layout()
out_barras = os.path.join(OUT_DIR, "barras_departamentos.png")
plt.savefig(out_barras, dpi=200)
plt.show()

out_barras
# Out:
# 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\salidas_tarea2\\barras_departamentos.png'

# %% [markdown]
# ## 5) Mapa coroplético a nivel departamental
# - Cargar **límites departamentales** (o **distritos** y `dissolve`).
# - Asegurar **CRS EPSG:4326**.
# - `merge` con `dep_resumen` y plot.

# %%
import geopandas as gpd
gdf_test = gpd.read_file(RUTA_LIMITE_DEPARTAMENTAL)
print(gdf_test.columns.tolist())
gdf_test.head(2)
# Out:
# ['shapeName', 'shapeISO', 'shapeID', 'shapeGroup', 'shapeType', 'geometry']
#   shapeName shapeISO                 shapeID shapeGroup shapeType  \
# 0      Puno   PE-PUN   1875124B3772980127380        PER      ADM1
# 1    Tumbes   PE-TUM  1875124B82769317880582        PER      ADM1
#
#                                                                                                                   geometry
# 0  POLYGON ((-69.58 -17.303, -69.612 -17.308, -69.635 -17.296, -69.666 -17.299, -69.696 -17.302, -69.719 -17.314, -69.7...
# 1  POLYGON ((-80.494 -4.0729, -80.519 -4.0913, -80.571 -4.1508, -80.591 -4.1824, -80.621 -4.2085, -80.651 -4.2085, -80....

# %%
import os, unicodedata
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# --- utilidades ---
def asegurar_crs_wgs84(gdf: gpd.GeoDataFrame) -> gpd.GeoDataFrame:
    if gdf.crs is None:
        gdf = gdf.set_crs(4326)
    else:
        gdf = gdf.to_crs(4326)
    return gdf

def _norm_dep(s) -> str:
    if s is None or (isinstance(s, float) and pd.isna(s)):
        return ""
    # quita acentos y pasa a mayúsculas
    s = str(s).strip()
    s = ''.join(ch for ch in unicodedata.normalize('NFKD', s) if not unicodedata.combining(ch))
    return s.upper()

# --- 1) leer el shapefile departamental ---
gdf_dep = gpd.read_file(RUTA_LIMITE_DEPARTAMENTAL)

# Tu shapefile usa 'shapeName' para el nombre del departamento
if "shapeName" in gdf_dep.columns:
    gdf_dep = gdf_dep.rename(columns={"shapeName": "Departamento"})
else:
    # fallback por si usas otro shape en el futuro
    posibles = ["DEPARTAMENTO","DEPARTAMEN","NOMBDEP","NAME_1","NOMBRE","NOMDEP","DEPTO"]
    col_dep = next((c for c in posibles if c in gdf_dep.columns), None)
    if not col_dep:
        raise KeyError(f"No encuentro columna de Departamento. Columnas: {list(gdf_dep.columns)}")
    gdf_dep = gdf_dep.rename(columns={col_dep: "Departamento"})

gdf_dep = gdf_dep[["Departamento", "geometry"]].copy()
gdf_dep = asegurar_crs_wgs84(gdf_dep)

# --- 2) normalizar nombres en ambos dataframes antes del merge ---
gdf_dep["DEP_NORM"] = gdf_dep["Departamento"].map(_norm_dep)
dep_resumen = dep_resumen.copy()
dep_resumen["DEP_NORM"] = dep_resumen["Departamento"].map(_norm_dep)

# --- 3) merge por nombre normalizado ---
gdf_dep = gdf_dep.merge(dep_resumen[["DEP_NORM","n_hospitales"]], on="DEP_NORM", how="left")

# diagnostiquemos posibles no empates ANTES de rellenar
faltantes = gdf_dep[gdf_dep["n_hospitales"].isna()][["Departamento"]]
print("Departamentos sin match:", len(faltantes))
if len(faltantes):
    print(faltantes.sort_values("Departamento").to_string(index=False))

gdf_dep["n_hospitales"] = gdf_dep["n_hospitales"].fillna(0).astype(int)

# --- 4) mapa ---
ax = gdf_dep.plot(column="n_hospitales", legend=True, edgecolor="black", linewidth=0.3)
ax.set_title("Hospitales públicos operativos por departamento")
ax.set_axis_off()
plt.tight_layout()
out_map = os.path.join(OUT_DIR, "mapa_departamental_coropletico.png")
plt.savefig(out_map, dpi=200)
plt.show()

out_map
# Out:
# Departamentos sin match: 6
#                        Departamento
#                           ApurÃ­mac
#                           El Callao
#                            HuÃ¡nuco
#                              JunÃ­n
# Municipalidad Metropolitana de Lima
#                         San MartÃ­n
# 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\salidas_tarea2\\mapa_departamental_coropletico.png'

# %% [markdown]
# # Tarea 3 – Proximity Analysis con Centros Poblados (Lima & Loreto)
#
# **Objetivo:** Calcular, para cada Centro Poblado (CCPP), cuántos **hospitales operativos** hay en un **radio de 10 km** y encontrar por departamento (Lima, Loreto) el CCPP con **menos** y **más** hospitales cerca. Visualizar cada caso con **Folium** (centroide, círculo 10 km y hospitales dentro).

# %%
import os, warnings, unicodedata
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

try:
    import folium
except ImportError:
    import sys
    !"{sys.executable}" -m pip install folium
    import folium

warnings.filterwarnings("ignore", category=UserWarning)
pd.set_option("display.max_colwidth", 120)

# %% [markdown]
# ## Parámetros (ajusta rutas)

# %%
# === Parámetros (actualiza esta celda) ===
import os, glob
from pathlib import Path

USAR_URL_IPRESS = True
URL_IPRESS = "https://datosabiertos.gob.pe/node/2998/download"

# Si usaras IPRESS local:
RUTA_IPRESS_LOCAL = r"C:\ruta\a\IPRESS.csv"

# ---- Centros Poblados (INEI) ----
# Tu carpeta real con los shapes de CCPP:
CARPETA_CCPP = r"C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\code\shape_file_CP"

# Auto-detecta el .shp dentro de esa carpeta
candidatos = glob.glob(os.path.join(CARPETA_CCPP, "*.shp"))
if not candidatos:
    raise FileNotFoundError(f"No encontré ningún .shp en: {CARPETA_CCPP}")

# Si hay varios, intenta preferir nombres que contengan 'centro', 'pob' o 'ccpp'
preferidos = [c for c in candidatos if any(k in os.path.basename(c).lower() for k in ("centro", "pob", "ccpp"))]
RUTA_CCPP = preferidos[0] if preferidos else candidatos[0]

# (Solo para GeoPackage .gpkg: define la capa. Aquí usamos .shp, así que None)
CAPA_CCPP = None

# Departamentos a analizar
DEPARTAMENTOS = ["LIMA", "LORETO"]

# Carpeta de salida
OUT_DIR = Path(r"C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\output")
OUT_DIR.mkdir(parents=True, exist_ok=True)
print("OUT_DIR ->", OUT_DIR)

print("Usando shapefile de CCPP:", RUTA_CCPP)
OUT_DIR
# Nombre de la columna de departamento en tu CCPP
COL_DEP_CCPP = "DEP"
# Out:
# OUT_DIR -> C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\output
# Usando shapefile de CCPP: C:\Users\User\Documents\PROFE_CHRISTIAN\Hospitals-Access-Peru\code\shape_file_CP\CCPP_IGN100K.shp

# %%
# Verificar que el shapefile existe y listar columnas (por si luego necesitamos la de Departamento)
import geopandas as gpd
gdf_tmp = gpd.read_file(RUTA_CCPP)
print("CRS:", gdf_tmp.crs)
print("Columnas:", gdf_tmp.columns.tolist()[:20])
len(gdf_tmp)
# Out:
# CRS: EPSG:4326
# Columnas: ['OBJECTID', 'NOM_POBLAD', 'FUENTE', 'CÓDIGO', 'CAT_POBLAD', 'DIST', 'PROV', 'DEP', 'CÓD_INT', 'CATEGORIA', 'X', 'Y', 'N_BUSQDA', 'geometry']
# 136587

# %% [markdown]
# ## Funciones base

# %%
def leer_centros_poblados(path: str, layer: str|None=None, col_dep_override: str|None=None) -> gpd.GeoDataFrame:
    import os
    if not path or not os.path.exists(path):
        raise FileNotFoundError(f"No encuentro Centros Poblados en: {path}")

    # Leer .gpkg o .shp
    if path.lower().endswith(".gpkg"):
        if not layer:
            import fiona
            raise ValueError(f"Para .gpkg define CAPA_CCPP. Capas: {fiona.listlayers(path)}")
        gdf = gpd.read_file(path, layer=layer)
    else:
        gdf = gpd.read_file(path)

    # 1) Detectar columna de Departamento (permite override)
    if col_dep_override and col_dep_override in gdf.columns:
        col_dep = col_dep_override
    else:
        candidatos = [
            "DEPARTAMENTO","DEPARTAMEN","DEPARTAM","NOMBDEP","REGION",
            "shapeName","NAME_1","DPTO","DEPTNAME","DEP"  # <-- agregado 'DEP'
        ]
        col_dep = next((c for c in candidatos if c in gdf.columns), None)
        if not col_dep:
            raise KeyError(f"No encuentro columna de Departamento en CCPP. Columnas: {list(gdf.columns)}")

    gdf = gdf.rename(columns={col_dep: "Departamento"})

    # 2) Geometría a puntos (si no lo fueran)
    if gdf.geom_type.iloc[0].upper() != "POINT":
        gdf["geometry"] = gdf.geometry.centroid

    # 3) Normalización y CRS
    gdf["DEP_NORM"] = gdf["Departamento"].map(_norm_txt)
    gdf = gdf[gdf.geometry.notna()].copy()
    gdf = gdf.set_crs(4326, allow_override=True) if gdf.crs is None else gdf.to_crs(4326)
    return gdf

# %% [markdown]
# ## Cargar datos (IPRESS + CCPP)

# %%
ipress_raw = leer_ipress(URL_IPRESS if USAR_URL_IPRESS else None,
                         RUTA_IPRESS_LOCAL if not USAR_URL_IPRESS else None)
ipress_hosp = preparar_hospitales(filtrar_hospitales_operativos(ipress_raw))

ccpp = leer_centros_poblados(RUTA_CCPP, CAPA_CCPP, col_dep_override=COL_DEP_CCPP)


len(ipress_hosp), ipress_hosp.crs, len(ccpp), ccpp.crs
# Out:
# (279,
#  <Geographic 2D CRS: EPSG:4326>
#  Name: WGS 84
#  Axis Info [ellipsoidal]:
#  - Lat[north]: Geodetic latitude (degree)
#  - Lon[east]: Geodetic longitude (degree)
#  Area of Use:
#  - name: World.
#  - bounds: (-180.0, -90.0, 180.0, 90.0)
#  Datum: World Geodetic System 1984 ensemble
#  - Ellipsoid: WGS 84
#  - Prime Meridian: Greenwich,
#  136587,
#  <Geographic 2D CRS: EPSG:4326>
#  Name: WGS 84
#  Axis Info [ellipsoidal]:
#  - Lat[north]: Geodetic latitude (degree)
#  - Lon[east]: Geodetic longitude (degree)
#  Area of Use:
#  - name: World.
#  - bounds: (-180.0, -90.0, 180.0, 90.0)
#  Datum: World Geodetic System 1984 ensemble
#  - Ellipsoid: WGS 84
#  - Prime Meridian: Greenwich)

# %% [markdown]
# ## Conteo de hospitales en 10 km

# %%
def contar_hospitales_en_radio(ccpp_region: gpd.GeoDataFrame,
                               hosp_4326: gpd.GeoDataFrame,
                               radio_metros: int = 10_000) -> gpd.GeoDataFrame:
    ccpp_utm = ccpp_region.to_crs(32718)
    if ccpp_utm.geom_type.iloc[0].upper() != "POINT":
        ccpp_utm["geometry"] = ccpp_utm.geometry.centroid
    buffers = ccpp_utm.copy()
    buffers["geometry"] = ccpp_utm.buffer(radio_metros)
    hosp_utm = hosp_4326.to_crs(32718)
    join = gpd.sjoin(hosp_utm[["geometry"]], buffers[["geometry"]], predicate="within", how="left")
    conteos = join.groupby(join.index_right).size()
    ccpp_utm["n_hospitales_10km"] = ccpp_utm.index.map(conteos).fillna(0).astype(int)
    ccpp_out = ccpp_utm.to_crs(4326)
    buffers_out = buffers.to_crs(4326)
    return ccpp_out, buffers_out

# %% [markdown]
# ## Ejecutar para Lima y Loreto y generar mapas Folium

# %%
def analizar_departamento(dep_nombre: str,
                          ccpp_all: gpd.GeoDataFrame,
                          hosp_4326: gpd.GeoDataFrame,
                          out_dir: str):
    dep_norm = _norm_txt(dep_nombre)
    ccpp_dep = ccpp_all[ccpp_all["DEP_NORM"] == dep_norm].copy()
    if ccpp_dep.empty:
        raise ValueError(f"No hay CCPP para el departamento: {dep_nombre}.")
    ccpp10, buf10 = contar_hospitales_en_radio(ccpp_dep, hosp_4326, 10_000)

    idx_min = ccpp10["n_hospitales_10km"].idxmin()
    idx_max = ccpp10["n_hospitales_10km"].idxmax()
    c_min = ccpp10.loc[idx_min]
    c_max = ccpp10.loc[idx_max]
    print(f"[{dep_nombre}] min={int(c_min['n_hospitales_10km'])} , max={int(c_max['n_hospitales_10km'])}")

    out_csv = os.path.join(out_dir, f"{dep_norm.lower()}_ccpp_conteo_10km.csv")
    ccpp10.drop(columns="geometry").to_csv(out_csv, index=False, encoding="utf-8")

    def _folium_caso(caso_row, titulo, fname):
        lat = caso_row.geometry.y
        lon = caso_row.geometry.x
        m = folium.Map(location=[lat, lon], zoom_start=9, control_scale=True)
        folium.Marker([lat, lon], tooltip=titulo, icon=folium.Icon(color="red")).add_to(m)
        folium.Circle([lat, lon], radius=10_000, fill=True, fill_opacity=0.1).add_to(m)
        # Filtrar hospitales dentro del buffer en UTM
        b_utm = gpd.GeoSeries([caso_row.geometry], crs=4326).to_crs(32718).buffer(10_000).iloc[0]
        hosp_utm = hosp_4326.to_crs(32718)
        inside_idx = hosp_utm[hosp_utm.within(b_utm)].index
        hosp_inside = hosp_4326.loc[inside_idx]
        for _, r in hosp_inside.iterrows():
            folium.CircleMarker([r.geometry.y, r.geometry.x], radius=4, tooltip="Hospital").add_to(m)
        out_html = os.path.join(out_dir, fname)
        m.save(out_html)
        return out_html

    h_min = _folium_caso(c_min, f"{dep_nombre}: menor disponibilidad ({int(c_min['n_hospitales_10km'])})", f"{dep_norm.lower()}_aislamiento_10km.html")
    h_max = _folium_caso(c_max, f"{dep_nombre}: mayor concentración ({int(c_max['n_hospitales_10km'])})", f"{dep_norm.lower()}_concentracion_10km.html")

    return {"dep": dep_nombre, "tabla": out_csv, "html_min": h_min, "html_max": h_max,
            "min_count": int(c_min["n_hospitales_10km"]), "max_count": int(c_max["n_hospitales_10km"])}

resultados = []
for dep in DEPARTAMENTOS:
    resultados.append(analizar_departamento(dep, ccpp, ipress_hosp, OUT_DIR))

resultados
# Out:
# [LIMA] min=0 , max=34
# [LORETO] min=0 , max=4
# [{'dep': 'LIMA',
#   'tabla': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\lima_ccpp_conteo_10km.csv',
#   'html_min': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\lima_aislamiento_10km.html',
#   'html_max': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\lima_concentracion_10km.html',
#   'min_count': 0,
#   'max_count': 34},
#  {'dep': 'LORETO',
#   'tabla': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\loreto_ccpp_conteo_10km.csv',
#   'html_min': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\loreto_aislamiento_10km.html',
#   'html_max': 'C:\\Users\\User\\Documents\\PROFE_CHRISTIAN\\Hospitals-Access-Peru\\output\\loreto_concentracion_10km.html',
#   'min_count': 0,
#   'max_count': 4}]
